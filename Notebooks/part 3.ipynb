# %% [markdown]
# # **Python Pandas Tutorial (Part 3): Indexes - How to Set, Reset, and Use Indexes**

# %%
import pandas as pd

# %%
pd.set_option('display.max_column', 150)

# %%
url= '../input/stack-overflow-2018-developer-survey/survey_results_public.csv'
df= pd.read_csv(url)

# %%
df.head(3)

# %% [markdown]
# # Setting up index
# We can do it to view our data using loc and in that we can put the value of the index column

# %%
df.set_index('DevType', inplace=True)

# %%
df.head(3)

# %%
df.index

# %% [markdown]
# # Reset index

# %%
df.reset_index(inplace=True)

# %%
df.head(3)

# %% [markdown]
# # Example of why setting index helps

# %%
url= "../input/stack-overflow-2018-developer-survey/survey_results_schema.csv"
schema= pd.read_csv(url)

# %%
schema.set_index('Column', inplace= True)

# %% [markdown]
# What does SurveyEasy means in df column

# %%
schema.loc["SurveyEasy"]

# %%
schema.loc["SurveyEasy", 'QuestionText']

# %% [markdown]
# # Sort index

# %%
schema.sort_index(inplace=True)

# %%
schema
